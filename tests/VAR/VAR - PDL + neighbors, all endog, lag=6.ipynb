# %% [markdown]
# ## #1 Importing libraries

# %%
import pandas as pd
import numpy as np
import datetime 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset
# **Adjusting each dataset to be only related to Pays de la Loire**
# - Hotel nights for regions bordering Pays de la loire
# - Weather for regions bordering Pays de la loire
# - Gross regional product
# - Days off
#
# Region |
# --- |
# Pays de la loire |
# Bretagne |
# Normandie |
# Centre Val de Loire |
# Nouvelle Aquitaine |

# %%
data_nights = pd.read_csv('/Users/jinny/Documents/touristcast/datasets/nights_2010-2017.csv')
data_nights = data_nights.drop('Unnamed: 0', axis=1)
data_nights

nights_PDL = data_nights[['date', 'nights_PDL', 'nights_BRE', 'nights_NOR', 'nights_CVL', 'nights_NAQ']]
nights_PDL['date'].apply(pd.to_datetime)
nights_PDL = nights_PDL.set_index('date')

nights_PDL

nights_PDL = nights_PDL.sort_values(by='date')
print(nights_PDL.info())
nights_PDL.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96 entries, 2010-01-01 to 2017-12-01
# Data columns (total 5 columns):
# nights_PDL    96 non-null float64
# nights_BRE    96 non-null float64
# nights_NOR    96 non-null float64
# nights_CVL    96 non-null float64
# nights_NAQ    96 non-null float64
# dtypes: float64(5)
# memory usage: 4.5+ KB
# None
#             nights_PDL  nights_BRE  nights_NOR  nights_CVL  nights_NAQ
# date
# 2010-01-01      333.33      273.63      341.09      253.94      602.06
# 2010-02-01      343.87      323.05      381.80      278.21      723.95
# 2010-03-01      446.19      433.01      492.98      379.48      916.84
# 2010-04-01      500.07      580.99      669.45      464.01     1218.11
# 2010-05-01      548.92      675.95      755.69      582.88     1352.00

# %%
data_temp = pd.read_csv('/Users/jinny/Documents/touristcast/datasets/avgtemp_2010-2017.csv')
data_temp = data_temp.drop('Unnamed: 0', axis=1)
data_temp

avgtemp_PDL = data_temp[['date', 'avgtemp_PDL', 'avgtemp_BRE', 'avgtemp_NOR', 'avgtemp_CVL', 'avgtemp_NAQ']]
avgtemp_PDL['date'].apply(pd.to_datetime)
avgtemp_PDL = avgtemp_PDL.set_index('date')

avgtemp_PDL

avgtemp_PDL = avgtemp_PDL.sort_values(by='date')
print(avgtemp_PDL.info())
avgtemp_PDL.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96 entries, 2010-01-01 to 2017-12-01
# Data columns (total 5 columns):
# avgtemp_PDL    96 non-null float64
# avgtemp_BRE    96 non-null float64
# avgtemp_NOR    96 non-null float64
# avgtemp_CVL    96 non-null float64
# avgtemp_NAQ    96 non-null float64
# dtypes: float64(5)
# memory usage: 4.5+ KB
# None
#             avgtemp_PDL  avgtemp_BRE  avgtemp_NOR  avgtemp_CVL  avgtemp_NAQ
# date
# 2010-01-01          4.0          6.0          4.0          2.0     4.886770
# 2010-02-01          7.0          7.0          6.0          4.0     6.088319
# 2010-03-01          8.0          8.0          8.0          7.0     9.088319
# 2010-04-01         13.0         12.0         11.0         12.0    13.781285
# 2010-05-01         14.0         13.0         13.0         14.0    14.596902

# %%
data_daysoff = pd.read_csv('/Users/jinny/Documents/touristcast/datasets/daysoff_2010-2017.csv', index_col='date')
data_daysoff = data_daysoff.drop('Unnamed: 0', axis=1)
data_daysoff.head()
# Out:
#             daysoff
# date
# 2010-01-01       11
# 2010-02-01        9
# 2010-03-01        9
# 2010-04-01       10
# 2010-05-01       12

# %%
data_gdp = pd.read_csv('/Users/jinny/Documents/touristcast/datasets/regionalGDP_2010-2015.csv')
data_gdp = data_gdp.drop('Unnamed: 0', axis=1)
data_gdp

gdp_PDL = data_gdp[['date', 'gdp_PDL', 'gdp_BRE', 'gdp_NOR', 'gdp_CVL', 'gdp_NAQ']]
gdp_PDL['date'].apply(pd.to_datetime)
gdp_PDL = gdp_PDL.set_index('date')

gdp_PDL

gdp_PDL = gdp_PDL.sort_values(by='date')
print(gdp_PDL.info())
gdp_PDL.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 2010-01-01 to 2015-12-01
# Data columns (total 5 columns):
# gdp_PDL    72 non-null float64
# gdp_BRE    72 non-null float64
# gdp_NOR    72 non-null float64
# gdp_CVL    72 non-null float64
# gdp_NAQ    72 non-null float64
# dtypes: float64(5)
# memory usage: 3.4+ KB
# None
#                  gdp_PDL       gdp_BRE       gdp_NOR       gdp_CVL  \
# date
# 2010-01-01  96709.073745  81299.450684  85549.671843  65690.501206
# 2010-02-01  96709.073745  81299.450684  85549.671843  65690.501206
# 2010-03-01  96709.073745  81299.450684  85549.671843  65690.501206
# 2010-04-01  96709.073745  81299.450684  85549.671843  65690.501206
# 2010-05-01  96709.073745  81299.450684  85549.671843  65690.501206
#
#                   gdp_NAQ
# date
# 2010-01-01  148172.239621
# 2010-02-01  148172.239621
# 2010-03-01  148172.239621
# 2010-04-01  148172.239621
# 2010-05-01  148172.239621

# %%
data_PDL_zone = pd.concat([nights_PDL, avgtemp_PDL, data_daysoff, gdp_PDL], axis=1, sort=False)
data_PDL_zone.index = pd.to_datetime(data_PDL_zone.index)
data_PDL_zone_train = data_PDL_zone.dropna(axis=0, how='any')
print(data_PDL_zone_train.info())
data_PDL_zone_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 72 entries, 2010-01-01 to 2015-12-01
# Data columns (total 16 columns):
# nights_PDL     72 non-null float64
# nights_BRE     72 non-null float64
# nights_NOR     72 non-null float64
# nights_CVL     72 non-null float64
# nights_NAQ     72 non-null float64
# avgtemp_PDL    72 non-null float64
# avgtemp_BRE    72 non-null float64
# avgtemp_NOR    72 non-null float64
# avgtemp_CVL    72 non-null float64
# avgtemp_NAQ    72 non-null float64
# daysoff        72 non-null int64
# gdp_PDL        72 non-null float64
# gdp_BRE        72 non-null float64
# gdp_NOR        72 non-null float64
# gdp_CVL        72 non-null float64
# gdp_NAQ        72 non-null float64
# dtypes: float64(15), int64(1)
# memory usage: 9.6 KB
# None
#             nights_PDL  nights_BRE  nights_NOR  nights_CVL  nights_NAQ  \
# 2010-01-01      333.33      273.63      341.09      253.94      602.06
# 2010-02-01      343.87      323.05      381.80      278.21      723.95
# 2010-03-01      446.19      433.01      492.98      379.48      916.84
# 2010-04-01      500.07      580.99      669.45      464.01     1218.11
# 2010-05-01      548.92      675.95      755.69      582.88     1352.00
#
#             avgtemp_PDL  avgtemp_BRE  avgtemp_NOR  avgtemp_CVL  avgtemp_NAQ  \
# 2010-01-01          4.0          6.0          4.0          2.0     4.886770
# 2010-02-01          7.0          7.0          6.0          4.0     6.088319
# 2010-03-01          8.0          8.0          8.0          7.0     9.088319
# 2010-04-01         13.0         12.0         11.0         12.0    13.781285
# 2010-05-01         14.0         13.0         13.0         14.0    14.596902
#
#             daysoff       gdp_PDL       gdp_BRE       gdp_NOR       gdp_CVL  \
# 2010-01-01       11  96709.073745  81299.450684  85549.671843  65690.501206
# 2010-02-01        9  96709.073745  81299.450684  85549.671843  65690.501206
# 2010-03-01        9  96709.073745  81299.450684  85549.671843  65690.501206
# 2010-04-01       10  96709.073745  81299.450684  85549.671843  65690.501206
# 2010-05-01       12  96709.073745  81299.450684  85549.671843  65690.501206
#
#                   gdp_NAQ
# 2010-01-01  148172.239621
# 2010-02-01  148172.239621
# 2010-03-01  148172.239621
# 2010-04-01  148172.239621
# 2010-05-01  148172.239621

# %% [markdown]
# ### Stationarity check

# %%
from statsmodels.tsa.stattools import adfuller

for column in data_PDL_zone_train.columns:
    result = adfuller(data_PDL_zone_train[column])
#     print(f'Stationarity test for variable {column}')
#     print('ADF Statistic: %f' % result[0])
#     print('p-value: %f' % result[1])
#     print('Critical Values:')

#     for key, value in result[4].items():
#         print('\t%s: %.3f' % (key, value))
    
    if result[1] < 0.05:
        print(f'{column}')
        print('Stationary')
        print('-------')
# Out:
# daysoff
# Stationary
# -------

# %% [markdown]
# Result:
# - Nights, AvgTemp, GDP are all non-stationary
# - Daysoff is stationary (also doesn't require forecasting as we already have the answers)

# %% [markdown]
# #### Figure out which series' seasonality is additive or multiplicative

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# ----- Additive Model below -----

add_data = seasonal_decompose(data_PDL_zone_train, model='additive')  

add_trend = add_data.trend.dropna()
add_seasonal = add_data.seasonal.dropna()
add_residual = add_data.resid.dropna()

# stationarity_test(add_residual)

# ----- Multiplicative Model below -----

mult_data = seasonal_decompose(data_PDL_zone_train, model='multiplicative')  

mult_trend = mult_data.trend.dropna()
mult_seasonal = mult_data.seasonal.dropna()
mult_residual = mult_data.resid.dropna()

# stationarity_test(mult_residual)

# %%
from statsmodels.tsa.stattools import acf

add_acfs = add_residual.apply(acf, axis=0).apply(np.square, axis=0).apply(np.sum)

mult_acfs = mult_residual.apply(acf, axis=0).apply(np.square, axis=0).apply(np.sum)

additive = add_acfs < mult_acfs
add_cols = additive.index[additive].tolist()
mult_cols = additive.index[~additive].tolist()
print('Additive:', add_cols)
print('Multiplicative', mult_cols)
# Out:
# Additive: ['nights_PDL', 'nights_NOR', 'nights_NAQ', 'daysoff']
# Multiplicative ['nights_BRE', 'nights_CVL', 'avgtemp_PDL', 'avgtemp_BRE', 'avgtemp_NOR', 'avgtemp_CVL', 'avgtemp_NAQ', 'gdp_PDL', 'gdp_BRE', 'gdp_NOR', 'gdp_CVL', 'gdp_NAQ']

# %% [markdown]
# > Nights in Pays de la Loire is an additive time series

# %% [markdown]
# ### Forecasting the 3 parts: Seasonal, Trend, and Residuals

# %% [markdown]
# #### Seasonal forecasts for 2016 (nights only)
# - Seasonal naive forecast method: Taking the same seasonal data as 2015

# %%
add_seasonal_2016 = add_seasonal[(add_seasonal.index>='2015-01-01')&(add_seasonal.index<'2016-01-01')]
add_seasonal_2016 = add_seasonal_2016[['nights_PDL']]
add_seasonal_2016.head()
# Out:
#             nights_PDL
# 2015-01-01 -169.663271
# 2015-02-01 -153.071438
# 2015-03-01  -83.517437
# 2015-04-01  -10.023021
# 2015-05-01   48.813063

# %% [markdown]
# #### Trend forecasts for 2016 (nights only)
# - non-seasonal forecasting methods ex. ARIMA or Holt's

# %%
from pyramid.arima import auto_arima
arima_trend = auto_arima(np.array(add_trend.nights_PDL), start_p=0, start_q=0, max_p=10, max_q=10, m=12,
                    start_P=0, max_P=10, seasonal=False, d=1, D=1, trace=True,
                    error_action='ignore', suppress_warnings=True, stepwise=False, random=True, random_state=42) 

arima_trend.summary()
# Out:
# Fit ARIMA: order=(6, 1, 3); AIC=189.030, BIC=211.883, Fit time=0.797 seconds
# Fit ARIMA: order=(8, 1, 2); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 0); AIC=242.666, BIC=246.821, Fit time=0.004 seconds
# Fit ARIMA: order=(5, 1, 0); AIC=197.106, BIC=211.649, Fit time=0.172 seconds
# Fit ARIMA: order=(0, 1, 5); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(9, 1, 0); AIC=194.071, BIC=216.924, Fit time=0.972 seconds
# Fit ARIMA: order=(1, 1, 5); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 1); AIC=204.095, BIC=212.405, Fit time=0.048 seconds
# Fit ARIMA: order=(10, 1, 0); AIC=195.575, BIC=220.505, Fit time=1.465 seconds
# Fit ARIMA: order=(3, 1, 0); AIC=199.633, BIC=210.020, Fit time=0.072 seconds
# Total fit time: 3.572 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                   59
# Model:                 ARIMA(6, 1, 3)   Log Likelihood                 -83.515
# Method:                       css-mle   S.D. of innovations              0.916
# Date:                Sun, 19 Aug 2018   AIC                            189.030
# Time:                        21:04:31   BIC                            211.883
# Sample:                             1   HQIC                           197.951
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8525      0.590      1.445      0.155      -0.304       2.009
# ar.L1.D.y      0.6516      0.147      4.442      0.000       0.364       0.939
# ar.L2.D.y     -0.3874      0.155     -2.496      0.016      -0.692      -0.083
# ar.L3.D.y      0.1351      0.162      0.834      0.408      -0.182       0.453
# ar.L4.D.y      0.0977      0.167      0.587      0.560      -0.229       0.424
# ar.L5.D.y      0.2156      0.166      1.300      0.200      -0.109       0.540
# ar.L6.D.y     -0.1601      0.134     -1.192      0.239      -0.423       0.103
# ma.L1.D.y      0.1595      0.125      1.277      0.208      -0.085       0.404
# ma.L2.D.y      0.1595      0.129      1.234      0.223      -0.094       0.413
# ma.L3.D.y      1.0000      0.136      7.356      0.000       0.734       1.266
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.1143           -0.9141j            1.4413           -0.3907
# AR.2           -1.1143           +0.9141j            1.4413            0.3907
# AR.3            0.2743           -1.1027j            1.1363           -0.2112
# AR.4            0.2743           +1.1027j            1.1363            0.2112
# AR.5            1.5132           -0.1972j            1.5260           -0.0206
# AR.6            1.5132           +0.1972j            1.5260            0.0206
# MA.1           -1.0000           -0.0000j            1.0000           -0.5000
# MA.2            0.4202           -0.9074j            1.0000           -0.1810
# MA.3            0.4202           +0.9074j            1.0000            0.1810
# -----------------------------------------------------------------------------
# """

# %%
arima_trend.fit(add_trend.nights_PDL)
# Out:
# ARIMA(callback=None, disp=0, maxiter=50, method=None, order=(6, 1, 3),
#    out_of_sample_size=0, scoring='mse', scoring_args={},
#    seasonal_order=None, solver='lbfgs', start_params=None,
#    suppress_warnings=True, transparams=True, trend='c')

# %%
arima_trend_forecast_2016 = arima_trend.predict(n_periods=12)
arima_trend_forecast_2016
# Out:
# array([552.93234163, 554.07130367, 555.28330746, 556.43649955,
#        557.45387436, 558.416607  , 559.29496733, 560.20489308,
#        561.12304384, 561.99772609, 562.84688727, 563.69101429])

# %%
arima_trend_forecast_2016_df = pd.DataFrame(arima_trend_forecast_2016)
arima_trend_forecast_2016_df.plot()

# %% [markdown]
# #### Residual forecasts for 2016 (produces forecasts for all but we will use nights forecast only)
# - VAR model
# - Takes all variables into account and gives predictions for all
# - We will be taking the VAR prediction for nights_PAC only

# %%
add_residual.head()
# Out:
#             nights_PDL  nights_BRE  nights_NOR  nights_CVL  nights_NAQ  \
# 2010-07-01   -2.689646    4.617104   36.673118    8.052285   29.166868
# 2010-08-01  -21.918062   13.136188   10.196868   13.251951  -31.572299
# 2010-09-01   -4.777396    2.690021   10.596035    7.404535  -11.006049
# 2010-10-01  -12.196479  -12.515229  -16.060382   -6.872632   -8.252465
# 2010-11-01   -2.692312  -22.831563  -33.113882  -15.791715  -17.810882
#
#             avgtemp_PDL  avgtemp_BRE  avgtemp_NOR  avgtemp_CVL  avgtemp_NAQ  \
# 2010-07-01     2.324306     1.803472     2.185417     2.529167     2.125103
# 2010-08-01     0.315972     0.236806     0.260417     0.529167     0.155126
# 2010-09-01    -0.509028    -0.538194    -0.239583    -0.470833    -0.879478
# 2010-10-01    -1.875694    -1.063194    -1.172917    -1.270833    -1.371127
# 2010-11-01    -1.400694    -1.354861    -0.906250    -1.237500    -1.460360
#
#              daysoff     gdp_PDL     gdp_BRE     gdp_NOR     gdp_CVL  \
# 2010-07-01  0.863889 -110.655228  -66.228940  -75.593194  -50.324587
# 2010-08-01 -1.311111 -331.965683 -198.686821 -226.779583 -150.973760
# 2010-09-01 -0.119444 -553.276139 -331.144701 -377.965972 -251.622934
# 2010-10-01  1.438889 -774.586595 -463.602581 -529.152361 -352.272107
# 2010-11-01 -0.061111 -995.897050 -596.060462 -680.338750 -452.921280
#
#                 gdp_NAQ
# 2010-07-01  -132.830626
# 2010-08-01  -398.491877
# 2010-09-01  -664.153129
# 2010-10-01  -929.814381
# 2010-11-01 -1195.475632

# %%
from statsmodels.tsa.api import VAR, DynamicVAR

model = VAR(add_residual, dates=add_residual.index)

lagorder_results = model.select_order(5)
print(lagorder_results.summary())

results = model.fit(maxlags=6, ic='aic')
print(results.summary())
# Out:
# /Users/jinny/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/jinny/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/vector_ar/var_model.py:1387: RuntimeWarning: invalid value encountered in sqrt
#   stderr = np.sqrt(np.diag(self.cov_params))
# /Users/jinny/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/jinny/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/jinny/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0       31.39       31.97   4.270e+13       31.61
# 1       49.22       59.14   3.312e+21       53.06
# 2       40.95       60.22   1.200e+19       48.40
# 3      -44.40      -15.79   1.439e-12      -33.33
# 4      -860.9      -822.9      0.000*      -846.2
# 5     -873.6*     -826.3*       0.000     -855.4*
# -------------------------------------------------
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 19, Aug, 2018
# Time:                     21:06:18
# --------------------------------------------------------------------
# No. of Equations:         16.0000    BIC:                   -827.292
# Nobs:                     54.0000    HQIC:                  -862.410
# Log likelihood:           24206.4    FPE:                    0.00000
# AIC:                     -884.457    Det(Omega_mle):         0.00000
# --------------------------------------------------------------------
# Results for equation nights_PDL
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.003198         0.000000        71021.324           0.000
# L1.nights_PDL          0.009966              NAN              NAN             NAN
# L1.nights_BRE          0.039094              NAN              NAN             NAN
# L1.nights_NOR         -0.221595              NAN              NAN             NAN
# L1.nights_CVL         -0.309011              NAN              NAN             NAN
# L1.nights_NAQ         -0.395594         0.000000     -7283417.283           0.000
# L1.avgtemp_PDL         0.298379              NAN              NAN             NAN
# L1.avgtemp_BRE         0.254358         0.000001       291055.085           0.000
# L1.avgtemp_NOR         0.202575              NAN              NAN             NAN
# L1.avgtemp_CVL         0.237436         0.000001       177135.671           0.000
# L1.avgtemp_NAQ         0.200416              NAN              NAN             NAN
# L1.daysoff             0.142716         0.000001       180433.093           0.000
# L1.gdp_PDL            -0.180653         0.000000    -97327691.977           0.000
# L1.gdp_BRE             0.155223              NAN              NAN             NAN
# L1.gdp_NOR             0.023564              NAN              NAN             NAN
# L1.gdp_CVL             0.112812              NAN              NAN             NAN
# L1.gdp_NAQ             0.006895              NAN              NAN             NAN
# L2.nights_PDL          0.775987              NAN              NAN             NAN
# L2.nights_BRE         -0.330900         0.000000     -5640694.834           0.000
# L2.nights_NOR         -0.209254         0.000000     -6373824.329           0.000
# L2.nights_CVL         -0.803270         0.000000     -8176688.021           0.000
# L2.nights_NAQ         -0.068048              NAN              NAN             NAN
# L2.avgtemp_PDL         0.155940         0.000000       473457.094           0.000
# L2.avgtemp_BRE         0.013862         0.000001        23876.614           0.000
# L2.avgtemp_NOR         0.153701              NAN              NAN             NAN
# L2.avgtemp_CVL         0.333361              NAN              NAN             NAN
# L2.avgtemp_NAQ         0.209142         0.000001       220026.906           0.000
# L2.daysoff            -0.455043         0.000000     -1135900.638           0.000
# L2.gdp_PDL            -0.165522              NAN              NAN             NAN
# L2.gdp_BRE             0.042377              NAN              NAN             NAN
# L2.gdp_NOR             0.056400         0.000000     19943217.635           0.000
# L2.gdp_CVL             0.141666         0.000000     19774474.850           0.000
# L2.gdp_NAQ             0.025306         0.000000     15443549.716           0.000
# L3.nights_PDL          0.447745              NAN              NAN             NAN
# L3.nights_BRE         -0.952577              NAN              NAN             NAN
# L3.nights_NOR         -0.032781              NAN              NAN             NAN
# L3.nights_CVL          0.476268              NAN              NAN             NAN
# L3.nights_NAQ          0.474819         0.000000     21182860.797           0.000
# L3.avgtemp_PDL         0.251062              NAN              NAN             NAN
# L3.avgtemp_BRE         0.269787         0.000001       224985.843           0.000
# L3.avgtemp_NOR         0.331118         0.000000       981197.235           0.000
# L3.avgtemp_CVL         0.390026              NAN              NAN             NAN
# L3.avgtemp_NAQ         0.347244         0.000001       533675.973           0.000
# L3.daysoff             0.016110         0.000000        59545.215           0.000
# L3.gdp_PDL            -0.128012         0.000000    -44568842.038           0.000
# L3.gdp_BRE             0.259346         0.000000     77537297.377           0.000
# L3.gdp_NOR            -0.077871              NAN              NAN             NAN
# L3.gdp_CVL             0.168128              NAN              NAN             NAN
# L3.gdp_NAQ            -0.043109              NAN              NAN             NAN
# L4.nights_PDL          0.304865              NAN              NAN             NAN
# L4.nights_BRE         -0.497105              NAN              NAN             NAN
# L4.nights_NOR         -0.227936         0.000000     -3132715.128           0.000
# L4.nights_CVL          0.391099         0.000000      9347825.204           0.000
# L4.nights_NAQ          0.185337              NAN              NAN             NAN
# L4.avgtemp_PDL         0.161278         0.000001       114009.308           0.000
# L4.avgtemp_BRE         0.034346         0.000000       134528.097           0.000
# L4.avgtemp_NOR         0.105753         0.000000       235277.672           0.000
# L4.avgtemp_CVL         0.234658              NAN              NAN             NAN
# L4.avgtemp_NAQ         0.014741              NAN              NAN             NAN
# L4.daysoff             0.041763         0.000001        71212.306           0.000
# L4.gdp_PDL             0.065600         0.000000     24890804.443           0.000
# L4.gdp_BRE             0.039340         0.000000     26800574.293           0.000
# L4.gdp_NOR            -0.060765         0.000000    -29525719.403           0.000
# L4.gdp_CVL             0.019275              NAN              NAN             NAN
# L4.gdp_NAQ            -0.042962              NAN              NAN             NAN
# L5.nights_PDL          0.830806              NAN              NAN             NAN
# L5.nights_BRE         -0.551154         0.000000    -26607935.778           0.000
# L5.nights_NOR         -0.078152         0.000000     -1541651.815           0.000
# L5.nights_CVL          0.063799         0.000000      1028214.216           0.000
# L5.nights_NAQ         -0.246882              NAN              NAN             NAN
# L5.avgtemp_PDL         0.017866         0.000001        20334.289           0.000
# L5.avgtemp_BRE        -0.037297              NAN              NAN             NAN
# L5.avgtemp_NOR        -0.122762         0.000000      -281454.898           0.000
# L5.avgtemp_CVL        -0.205443              NAN              NAN             NAN
# L5.avgtemp_NAQ        -0.139399         0.000001      -165780.692           0.000
# L5.daysoff             0.111932              NAN              NAN             NAN
# L5.gdp_PDL            -0.053521              NAN              NAN             NAN
# L5.gdp_BRE            -0.065044              NAN              NAN             NAN
# L5.gdp_NOR             0.017866              NAN              NAN             NAN
# L5.gdp_CVL             0.058395              NAN              NAN             NAN
# L5.gdp_NAQ             0.047148              NAN              NAN             NAN
# L6.nights_PDL          0.689143              NAN              NAN             NAN
# L6.nights_BRE          0.197037         0.000000      2754687.652           0.000
# L6.nights_NOR         -0.037562         0.000000     -1303074.874           0.000
# L6.nights_CVL         -0.244615              NAN              NAN             NAN
# L6.nights_NAQ         -0.455371              NAN              NAN             NAN
# L6.avgtemp_PDL         0.132765         0.000001       130304.726           0.000
# L6.avgtemp_BRE         0.036578         0.000001        62927.342           0.000
# L6.avgtemp_NOR         0.119005         0.000001       121559.014           0.000
# L6.avgtemp_CVL         0.416690              NAN              NAN             NAN
# L6.avgtemp_NAQ         0.227614         0.000001       341353.025           0.000
# L6.daysoff            -0.119717              NAN              NAN             NAN
# L6.gdp_PDL             0.270352         0.000000    453522677.333           0.000
# L6.gdp_BRE            -0.261955         0.000000   -136027830.592           0.000
# L6.gdp_NOR             0.035485         0.000000      6651039.916           0.000
# L6.gdp_CVL            -0.255308              NAN              NAN             NAN
# L6.gdp_NAQ            -0.012247              NAN              NAN             NAN
# =================================================================================
#
# Results for equation nights_BRE
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.102380         0.000000      1119967.857           0.000
# L1.nights_PDL         -0.224522              NAN              NAN             NAN
# L1.nights_BRE         -0.559965              NAN              NAN             NAN
# L1.nights_NOR          0.496360              NAN              NAN             NAN
# L1.nights_CVL         -0.095704              NAN              NAN             NAN
# L1.nights_NAQ         -0.107767         0.000000      -977470.447           0.000
# L1.avgtemp_PDL         0.712762              NAN              NAN             NAN
# L1.avgtemp_BRE         0.636088         0.000002       358574.607           0.000
# L1.avgtemp_NOR         0.590512              NAN              NAN             NAN
# L1.avgtemp_CVL         0.607511         0.000003       223278.124           0.000
# L1.avgtemp_NAQ         0.486243              NAN              NAN             NAN
# L1.daysoff             0.091467         0.000002        56968.985           0.000
# L1.gdp_PDL            -0.417282         0.000000   -110752491.853           0.000
# L1.gdp_BRE             0.271358              NAN              NAN             NAN
# L1.gdp_NOR             0.067779              NAN              NAN             NAN
# L1.gdp_CVL             0.289007              NAN              NAN             NAN
# L1.gdp_NAQ             0.050705              NAN              NAN             NAN
# L2.nights_PDL          0.836850              NAN              NAN             NAN
# L2.nights_BRE         -0.110355         0.000000      -926749.003           0.000
# L2.nights_NOR         -0.031687         0.000000      -475493.023           0.000
# L2.nights_CVL         -0.676460         0.000000     -3392278.928           0.000
# L2.nights_NAQ         -0.304603              NAN              NAN             NAN
# L2.avgtemp_PDL         0.138944         0.000001       207823.762           0.000
# L2.avgtemp_BRE         0.039369         0.000001        33406.686           0.000
# L2.avgtemp_NOR         0.167490              NAN              NAN             NAN
# L2.avgtemp_CVL         0.414695              NAN              NAN             NAN
# L2.avgtemp_NAQ         0.306009         0.000002       158599.507           0.000
# L2.daysoff            -0.659206         0.000001      -810667.052           0.000
# L2.gdp_PDL            -0.030754              NAN              NAN             NAN
# L2.gdp_BRE            -0.034239              NAN              NAN             NAN
# L2.gdp_NOR             0.052261         0.000000      9103922.835           0.000
# L2.gdp_CVL             0.001223         0.000000        84107.379           0.000
# L2.gdp_NAQ             0.005747         0.000000      1727832.036           0.000
# L3.nights_PDL          1.113573              NAN              NAN             NAN
# L3.nights_BRE         -1.169633              NAN              NAN             NAN
# L3.nights_NOR          0.004982              NAN              NAN             NAN
# L3.nights_CVL          0.128359              NAN              NAN             NAN
# L3.nights_NAQ          0.818557         0.000000     17990304.874           0.000
# L3.avgtemp_PDL         0.473617              NAN              NAN             NAN
# L3.avgtemp_BRE         0.470666         0.000002       193366.180           0.000
# L3.avgtemp_NOR         0.614045         0.000001       896412.465           0.000
# L3.avgtemp_CVL         0.617221              NAN              NAN             NAN
# L3.avgtemp_NAQ         0.550814         0.000001       417043.452           0.000
# L3.daysoff             0.209213         0.000001       380959.856           0.000
# L3.gdp_PDL            -0.018372         0.000000     -3151189.847           0.000
# L3.gdp_BRE             0.006043         0.000000       890094.774           0.000
# L3.gdp_NOR            -0.049911              NAN              NAN             NAN
# L3.gdp_CVL             0.115941              NAN              NAN             NAN
# L3.gdp_NAQ             0.008932              NAN              NAN             NAN
# L4.nights_PDL          0.645942              NAN              NAN             NAN
# L4.nights_BRE         -0.553815              NAN              NAN             NAN
# L4.nights_NOR          0.097151         0.000000       657791.794           0.000
# L4.nights_CVL          0.529659         0.000000      6236686.609           0.000
# L4.nights_NAQ          0.434973              NAN              NAN             NAN
# L4.avgtemp_PDL         0.321483         0.000003       111958.141           0.000
# L4.avgtemp_BRE         0.160729         0.000001       310139.506           0.000
# L4.avgtemp_NOR         0.233531         0.000001       255955.875           0.000
# L4.avgtemp_CVL         0.458322              NAN              NAN             NAN
# L4.avgtemp_NAQ         0.141042              NAN              NAN             NAN
# L4.daysoff            -0.060376         0.000001       -50717.853           0.000
# L4.gdp_PDL             0.221466         0.000000     41397815.279           0.000
# L4.gdp_BRE             0.010341         0.000000      3470568.676           0.000
# L4.gdp_NOR            -0.144218         0.000000    -34522019.766           0.000
# L4.gdp_CVL            -0.088470              NAN              NAN             NAN
# L4.gdp_NAQ            -0.109216              NAN              NAN             NAN
# L5.nights_PDL          0.206807              NAN              NAN             NAN
# L5.nights_BRE         -0.239552         0.000000     -5697324.019           0.000
# L5.nights_NOR          0.001069         0.000000        10388.761           0.000
# L5.nights_CVL          0.377339         0.000000      2995965.430           0.000
# L5.nights_NAQ         -0.067233              NAN              NAN             NAN
# L5.avgtemp_PDL         0.108131         0.000002        60630.315           0.000
# L5.avgtemp_BRE        -0.013653              NAN              NAN             NAN
# L5.avgtemp_NOR        -0.071316         0.000001       -80549.728           0.000
# L5.avgtemp_CVL        -0.183912              NAN              NAN             NAN
# L5.avgtemp_NAQ        -0.236739         0.000002      -138700.165           0.000
# L5.daysoff             0.177096              NAN              NAN             NAN
# L5.gdp_PDL            -0.174716              NAN              NAN             NAN
# L5.gdp_BRE             0.094662              NAN              NAN             NAN
# L5.gdp_NOR             0.006444              NAN              NAN             NAN
# L5.gdp_CVL             0.194468              NAN              NAN             NAN
# L5.gdp_NAQ             0.054491              NAN              NAN             NAN
# L6.nights_PDL          1.114221              NAN              NAN             NAN
# L6.nights_BRE          0.488412         0.000000      3363899.594           0.000
# L6.nights_NOR         -0.161164         0.000000     -2754371.696           0.000
# L6.nights_CVL         -0.455630              NAN              NAN             NAN
# L6.nights_NAQ         -0.686849              NAN              NAN             NAN
# L6.avgtemp_PDL         0.333817         0.000002       161404.919           0.000
# L6.avgtemp_BRE         0.216006         0.000001       183069.560           0.000
# L6.avgtemp_NOR         0.263045         0.000002       132368.948           0.000
# L6.avgtemp_CVL         0.708035              NAN              NAN             NAN
# L6.avgtemp_NAQ         0.485874         0.000001       358973.851           0.000
# L6.daysoff            -0.374691              NAN              NAN             NAN
# L6.gdp_PDL             0.374215         0.000000    309260401.279           0.000
# L6.gdp_BRE            -0.378778         0.000000    -96899140.006           0.000
# L6.gdp_NOR             0.034417         0.000000      3177925.731           0.000
# L6.gdp_CVL            -0.382922              NAN              NAN             NAN
# L6.gdp_NAQ            -0.013324              NAN              NAN             NAN
# =================================================================================
#
# Results for equation nights_NOR
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.182579         0.000000      2098888.694           0.000
# L1.nights_PDL         -0.544868              NAN              NAN             NAN
# L1.nights_BRE         -0.234239              NAN              NAN             NAN
# L1.nights_NOR          0.586288              NAN              NAN             NAN
# L1.nights_CVL         -0.787888              NAN              NAN             NAN
# L1.nights_NAQ          0.117220         0.000000      1117295.950           0.000
# L1.avgtemp_PDL         0.032355              NAN              NAN             NAN
# L1.avgtemp_BRE         0.040564         0.000002        24029.790           0.000
# L1.avgtemp_NOR         0.050336              NAN              NAN             NAN
# L1.avgtemp_CVL         0.019592         0.000003         7566.769           0.000
# L1.avgtemp_NAQ        -0.026667              NAN              NAN             NAN
# L1.daysoff            -0.146927         0.000002       -96167.069           0.000
# L1.gdp_PDL            -0.081792         0.000000    -22812928.677           0.000
# L1.gdp_BRE            -0.003046              NAN              NAN             NAN
# L1.gdp_NOR             0.031043              NAN              NAN             NAN
# L1.gdp_CVL             0.059189              NAN              NAN             NAN
# L1.gdp_NAQ             0.033648              NAN              NAN             NAN
# L2.nights_PDL         -0.095117              NAN              NAN             NAN
# L2.nights_BRE          0.276462         0.000000      2439793.588           0.000
# L2.nights_NOR         -0.478877         0.000000     -7551460.949           0.000
# L2.nights_CVL          0.531490         0.000000      2800865.622           0.000
# L2.nights_NAQ         -0.233223              NAN              NAN             NAN
# L2.avgtemp_PDL        -0.000571         0.000001         -897.737           0.000
# L2.avgtemp_BRE         0.039830         0.000001        35517.066           0.000
# L2.avgtemp_NOR         0.008942              NAN              NAN             NAN
# L2.avgtemp_CVL        -0.053507              NAN              NAN             NAN
# L2.avgtemp_NAQ        -0.014407         0.000002        -7846.943           0.000
# L2.daysoff            -0.083938         0.000001      -108474.424           0.000
# L2.gdp_PDL             0.066863              NAN              NAN             NAN
# L2.gdp_BRE            -0.188616              NAN              NAN             NAN
# L2.gdp_NOR             0.030115         0.000000      5512977.031           0.000
# L2.gdp_CVL            -0.080422         0.000000     -5811605.814           0.000
# L2.gdp_NAQ             0.034180         0.000000     10798825.461           0.000
# L3.nights_PDL         -0.093671              NAN              NAN             NAN
# L3.nights_BRE          0.351927              NAN              NAN             NAN
# L3.nights_NOR         -0.172370              NAN              NAN             NAN
# L3.nights_CVL         -0.989557              NAN              NAN             NAN
# L3.nights_NAQ          0.480642         0.000000     11100912.243           0.000
# L3.avgtemp_PDL         0.065930              NAN              NAN             NAN
# L3.avgtemp_BRE         0.103302         0.000002        44599.125           0.000
# L3.avgtemp_NOR         0.096470         0.000001       147995.752           0.000
# L3.avgtemp_CVL         0.042724              NAN              NAN             NAN
# L3.avgtemp_NAQ         0.110349         0.000001        87799.738           0.000
# L3.daysoff             0.179533         0.000001       343543.612           0.000
# L3.gdp_PDL            -0.027964         0.000000     -5040439.736           0.000
# L3.gdp_BRE             0.074481         0.000000     11528142.030           0.000
# L3.gdp_NOR            -0.013182              NAN              NAN             NAN
# L3.gdp_CVL             0.061770              NAN              NAN             NAN
# L3.gdp_NAQ             0.014771              NAN              NAN             NAN
# L4.nights_PDL          0.197659              NAN              NAN             NAN
# L4.nights_BRE         -0.370188              NAN              NAN             NAN
# L4.nights_NOR          0.191609         0.000000      1363346.138           0.000
# L4.nights_CVL          0.282656         0.000000      3497550.350           0.000
# L4.nights_NAQ          0.000409              NAN              NAN             NAN
# L4.avgtemp_PDL        -0.062115         0.000003       -22732.244           0.000
# L4.avgtemp_BRE        -0.013901         0.000000       -28187.996           0.000
# L4.avgtemp_NOR        -0.021226         0.000001       -24447.564           0.000
# L4.avgtemp_CVL        -0.023979              NAN              NAN             NAN
# L4.avgtemp_NAQ        -0.009121              NAN              NAN             NAN
# L4.daysoff             0.083853         0.000001        74022.635           0.000
# L4.gdp_PDL             0.100954         0.000000     19830793.550           0.000
# L4.gdp_BRE             0.028747         0.000000     10138696.428           0.000
# L4.gdp_NOR            -0.054508         0.000000    -13711522.268           0.000
# L4.gdp_CVL            -0.083430              NAN              NAN             NAN
# L4.gdp_NAQ            -0.092148              NAN              NAN             NAN
# L5.nights_PDL          0.024024              NAN              NAN             NAN
# L5.nights_BRE         -0.338658         0.000000     -8464111.716           0.000
# L5.nights_NOR         -0.784982         0.000000     -8016564.665           0.000
# L5.nights_CVL          0.895270         0.000000      7469765.331           0.000
# L5.nights_NAQ          0.285284              NAN              NAN             NAN
# L5.avgtemp_PDL        -0.039695         0.000002       -23389.855           0.000
# L5.avgtemp_BRE        -0.031132              NAN              NAN             NAN
# L5.avgtemp_NOR        -0.015426         0.000001       -18309.367           0.000
# L5.avgtemp_CVL        -0.020215              NAN              NAN             NAN
# L5.avgtemp_NAQ        -0.120928         0.000002       -74452.832           0.000
# L5.daysoff            -0.128063              NAN              NAN             NAN
# L5.gdp_PDL            -0.080765              NAN              NAN             NAN
# L5.gdp_BRE             0.192685              NAN              NAN             NAN
# L5.gdp_NOR            -0.026719              NAN              NAN             NAN
# L5.gdp_CVL             0.097372              NAN              NAN             NAN
# L5.gdp_NAQ            -0.001942              NAN              NAN             NAN
# L6.nights_PDL         -0.627303              NAN              NAN             NAN
# L6.nights_BRE         -0.092528         0.000000      -669694.381           0.000
# L6.nights_NOR          0.536418         0.000000      9634004.537           0.000
# L6.nights_CVL         -0.187165              NAN              NAN             NAN
# L6.nights_NAQ         -0.090246              NAN              NAN             NAN
# L6.avgtemp_PDL         0.201415         0.000002       102340.483           0.000
# L6.avgtemp_BRE         0.158080         0.000001       140790.711           0.000
# L6.avgtemp_NOR         0.154382         0.000002        81639.527           0.000
# L6.avgtemp_CVL         0.134439              NAN              NAN             NAN
# L6.avgtemp_NAQ         0.107238         0.000001        83259.413           0.000
# L6.daysoff            -0.081886              NAN              NAN             NAN
# L6.gdp_PDL             0.023289         0.000000     20225813.384           0.000
# L6.gdp_BRE            -0.091742         0.000000    -24663198.477           0.000
# L6.gdp_NOR             0.011862         0.000000      1150985.256           0.000
# L6.gdp_CVL            -0.041493              NAN              NAN             NAN
# L6.gdp_NAQ             0.014690              NAN              NAN             NAN
# =================================================================================
#
# Results for equation nights_CVL
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -0.050510         0.000000      -981985.700           0.000
# L1.nights_PDL         -0.096817              NAN              NAN             NAN
# L1.nights_BRE         -0.150082              NAN              NAN             NAN
# L1.nights_NOR          0.174980              NAN              NAN             NAN
# L1.nights_CVL         -0.193769              NAN              NAN             NAN
# L1.nights_NAQ         -0.162531         0.000000     -2619921.013           0.000
# L1.avgtemp_PDL         0.294529              NAN              NAN             NAN
# L1.avgtemp_BRE         0.270688         0.000001       271185.014           0.000
# L1.avgtemp_NOR         0.237628              NAN              NAN             NAN
# L1.avgtemp_CVL         0.217686         0.000002       142185.968           0.000
# L1.avgtemp_NAQ         0.154424              NAN              NAN             NAN
# L1.daysoff             0.096970         0.000001       107336.790           0.000
# L1.gdp_PDL            -0.280000         0.000000   -132073836.678           0.000
# L1.gdp_BRE             0.218223              NAN              NAN             NAN
# L1.gdp_NOR             0.041001              NAN              NAN             NAN
# L1.gdp_CVL             0.197787              NAN              NAN             NAN
# L1.gdp_NAQ             0.009385              NAN              NAN             NAN
# L2.nights_PDL          0.418202              NAN              NAN             NAN
# L2.nights_BRE          0.110022         0.000000      1642041.370           0.000
# L2.nights_NOR         -0.265267         0.000000     -7074191.740           0.000
# L2.nights_CVL         -0.653368         0.000000     -5822929.775           0.000
# L2.nights_NAQ         -0.014354              NAN              NAN             NAN
# L2.avgtemp_PDL         0.127996         0.000000       340242.734           0.000
# L2.avgtemp_BRE         0.021194         0.000001        31962.000           0.000
# L2.avgtemp_NOR         0.115457              NAN              NAN             NAN
# L2.avgtemp_CVL         0.266227              NAN              NAN             NAN
# L2.avgtemp_NAQ         0.165180         0.000001       152145.394           0.000
# L2.daysoff            -0.359444         0.000000      -785575.482           0.000
# L2.gdp_PDL             0.086498              NAN              NAN             NAN
# L2.gdp_BRE            -0.090411              NAN              NAN             NAN
# L2.gdp_NOR             0.027576         0.000000      8537048.409           0.000
# L2.gdp_CVL            -0.094734         0.000000    -11577413.701           0.000
# L2.gdp_NAQ             0.000110         0.000000        58656.245           0.000
# L3.nights_PDL          0.351490              NAN              NAN             NAN
# L3.nights_BRE         -0.711729              NAN              NAN             NAN
# L3.nights_NOR         -0.045027              NAN              NAN             NAN
# L3.nights_CVL          0.070322              NAN              NAN             NAN
# L3.nights_NAQ          0.467117         0.000000     18245227.646           0.000
# L3.avgtemp_PDL         0.293441              NAN              NAN             NAN
# L3.avgtemp_BRE         0.282654         0.000001       206375.342           0.000
# L3.avgtemp_NOR         0.338603         0.000000       878482.935           0.000
# L3.avgtemp_CVL         0.379765              NAN              NAN             NAN
# L3.avgtemp_NAQ         0.365246         0.000001       491469.098           0.000
# L3.daysoff             0.016599         0.000000        53716.171           0.000
# L3.gdp_PDL            -0.078993         0.000000    -24078834.163           0.000
# L3.gdp_BRE             0.054564         0.000000     14282384.214           0.000
# L3.gdp_NOR            -0.048425              NAN              NAN             NAN
# L3.gdp_CVL             0.123951              NAN              NAN             NAN
# L3.gdp_NAQ             0.018181              NAN              NAN             NAN
# L4.nights_PDL          0.362341              NAN              NAN             NAN
# L4.nights_BRE         -0.249452              NAN              NAN             NAN
# L4.nights_NOR          0.061212         0.000000       736572.869           0.000
# L4.nights_CVL          0.256732         0.000000      5372443.418           0.000
# L4.nights_NAQ          0.038218              NAN              NAN             NAN
# L4.avgtemp_PDL         0.167719         0.000002       103804.089           0.000
# L4.avgtemp_BRE         0.079870         0.000000       273895.528           0.000
# L4.avgtemp_NOR         0.116756         0.000001       227422.222           0.000
# L4.avgtemp_CVL         0.235588              NAN              NAN             NAN
# L4.avgtemp_NAQ         0.080107              NAN              NAN             NAN
# L4.daysoff             0.000330         0.000001          492.132           0.000
# L4.gdp_PDL             0.132961         0.000000     44170073.369           0.000
# L4.gdp_BRE             0.043248         0.000000     25795140.265           0.000
# L4.gdp_NOR            -0.081979         0.000000    -34874962.075           0.000
# L4.gdp_CVL            -0.028654              NAN              NAN             NAN
# L4.gdp_NAQ            -0.083300              NAN              NAN             NAN
# L5.nights_PDL          0.337958              NAN              NAN             NAN
# L5.nights_BRE         -0.058375         0.000000     -2467379.768           0.000
# L5.nights_NOR         -0.079120         0.000000     -1366475.307           0.000
# L5.nights_CVL          0.374949         0.000000      5290679.220           0.000
# L5.nights_NAQ         -0.376982              NAN              NAN             NAN
# L5.avgtemp_PDL         0.001498         0.000001         1492.292           0.000
# L5.avgtemp_BRE        -0.045758              NAN              NAN             NAN
# L5.avgtemp_NOR        -0.099447         0.000000      -199619.466           0.000
# L5.avgtemp_CVL        -0.169897              NAN              NAN             NAN
# L5.avgtemp_NAQ        -0.154028         0.000001      -160376.769           0.000
# L5.daysoff             0.111402              NAN              NAN             NAN
# L5.gdp_PDL            -0.053061              NAN              NAN             NAN
# L5.gdp_BRE             0.010678              NAN              NAN             NAN
# L5.gdp_NOR            -0.000559              NAN              NAN             NAN
# L5.gdp_CVL             0.065923              NAN              NAN             NAN
# L5.gdp_NAQ             0.024691              NAN              NAN             NAN
# L6.nights_PDL          0.577402              NAN              NAN             NAN
# L6.nights_BRE          0.336968         0.000000      4124585.994           0.000
# L6.nights_NOR         -0.251447         0.000000     -7637233.445           0.000
# L6.nights_CVL         -0.053914              NAN              NAN             NAN
# L6.nights_NAQ         -0.457914              NAN              NAN             NAN
# L6.avgtemp_PDL         0.111678         0.000001        95964.499           0.000
# L6.avgtemp_BRE         0.041322         0.000001        62239.707           0.000
# L6.avgtemp_NOR         0.094227         0.000001        84268.827           0.000
# L6.avgtemp_CVL         0.307456              NAN              NAN             NAN
# L6.avgtemp_NAQ         0.149546         0.000001       196357.469           0.000
# L6.daysoff            -0.126888              NAN              NAN             NAN
# L6.gdp_PDL             0.133645         0.000000    196285993.959           0.000
# L6.gdp_BRE            -0.173011         0.000000    -78658280.720           0.000
# L6.gdp_NOR             0.047763         0.000000      7837928.358           0.000
# L6.gdp_CVL            -0.131995              NAN              NAN             NAN
# L6.gdp_NAQ             0.004889              NAN              NAN             NAN
# =================================================================================
#
# Results for equation nights_NAQ
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -0.355089         0.000000     -3397986.932           0.000
# L1.nights_PDL          0.358650              NAN              NAN             NAN
# L1.nights_BRE         -0.385446              NAN              NAN             NAN
# L1.nights_NOR          0.339892              NAN              NAN             NAN
# L1.nights_CVL         -0.522578              NAN              NAN             NAN
# L1.nights_NAQ         -0.501466         0.000000     -3978804.473           0.000
# L1.avgtemp_PDL         0.732981              NAN              NAN             NAN
# L1.avgtemp_BRE         0.694416         0.000002       342432.514           0.000
# L1.avgtemp_NOR         0.569276              NAN              NAN             NAN
# L1.avgtemp_CVL         0.625464         0.000003       201088.410           0.000
# L1.avgtemp_NAQ         0.548721              NAN              NAN             NAN
# L1.daysoff             0.180930         0.000002        98577.595           0.000
# L1.gdp_PDL            -0.566849         0.000000   -131608362.058           0.000
# L1.gdp_BRE             0.405510              NAN              NAN             NAN
# L1.gdp_NOR             0.075877              NAN              NAN             NAN
# L1.gdp_CVL             0.444577              NAN              NAN             NAN
# L1.gdp_NAQ             0.041111              NAN              NAN             NAN
# L2.nights_PDL          1.274535              NAN              NAN             NAN
# L2.nights_BRE          0.119714         0.000000       879443.228           0.000
# L2.nights_NOR         -0.268415         0.000000     -3523376.725           0.000
# L2.nights_CVL         -0.992270         0.000000     -4352832.654           0.000
# L2.nights_NAQ         -0.247914              NAN              NAN             NAN
# L2.avgtemp_PDL         0.170005         0.000001       222439.435           0.000
# L2.avgtemp_BRE        -0.039270         0.000001       -29149.794           0.000
# L2.avgtemp_NOR         0.224518              NAN              NAN             NAN
# L2.avgtemp_CVL         0.524057              NAN              NAN             NAN
# L2.avgtemp_NAQ         0.363478         0.000002       164793.010           0.000
# L2.daysoff            -0.734077         0.000001      -789689.388           0.000
# L2.gdp_PDL             0.246277              NAN              NAN             NAN
# L2.gdp_BRE            -0.255693              NAN              NAN             NAN
# L2.gdp_NOR             0.039037         0.000000      5948712.339           0.000
# L2.gdp_CVL            -0.251444         0.000000    -15125365.102           0.000
# L2.gdp_NAQ            -0.001727         0.000000      -454108.384           0.000
# L3.nights_PDL          0.803912              NAN              NAN             NAN
# L3.nights_BRE         -1.852371              NAN              NAN             NAN
# L3.nights_NOR          0.125964              NAN              NAN             NAN
# L3.nights_CVL          0.357309              NAN              NAN             NAN
# L3.nights_NAQ          1.627546         0.000000     31290709.515           0.000
# L3.avgtemp_PDL         0.680182              NAN              NAN             NAN
# L3.avgtemp_BRE         0.668157         0.000003       240126.331           0.000
# L3.avgtemp_NOR         0.795751         0.000001      1016196.680           0.000
# L3.avgtemp_CVL         0.870607              NAN              NAN             NAN
# L3.avgtemp_NAQ         0.794412         0.000002       526156.488           0.000
# L3.daysoff             0.099417         0.000001       158360.073           0.000
# L3.gdp_PDL            -0.273061         0.000000    -40970058.925           0.000
# L3.gdp_BRE             0.176258         0.000000     22709369.365           0.000
# L3.gdp_NOR            -0.012616              NAN              NAN             NAN
# L3.gdp_CVL             0.353943              NAN              NAN             NAN
# L3.gdp_NAQ             0.036080              NAN              NAN             NAN
# L4.nights_PDL          0.198484              NAN              NAN             NAN
# L4.nights_BRE         -0.517968              NAN              NAN             NAN
# L4.nights_NOR          0.345414         0.000000      2045852.884           0.000
# L4.nights_CVL          0.946447         0.000000      9748699.282           0.000
# L4.nights_NAQ          0.345392              NAN              NAN             NAN
# L4.avgtemp_PDL         0.357398         0.000003       108878.740           0.000
# L4.avgtemp_BRE         0.145264         0.000001       245196.476           0.000
# L4.avgtemp_NOR         0.270527         0.000001       259372.910           0.000
# L4.avgtemp_CVL         0.548390              NAN              NAN             NAN
# L4.avgtemp_NAQ         0.110920              NAN              NAN             NAN
# L4.daysoff            -0.078246         0.000001       -57498.101           0.000
# L4.gdp_PDL             0.463210         0.000000     75742720.133           0.000
# L4.gdp_BRE            -0.083641         0.000000    -24555627.387           0.000
# L4.gdp_NOR            -0.190159         0.000000    -39818755.369           0.000
# L4.gdp_CVL            -0.338968              NAN              NAN             NAN
# L4.gdp_NAQ            -0.149821              NAN              NAN             NAN
# L5.nights_PDL          0.528565              NAN              NAN             NAN
# L5.nights_BRE         -0.206435         0.000000     -4294843.823           0.000
# L5.nights_NOR          0.095614         0.000000       812821.242           0.000
# L5.nights_CVL         -0.255261         0.000000     -1772894.206           0.000
# L5.nights_NAQ         -0.338868              NAN              NAN             NAN
# L5.avgtemp_PDL         0.141039         0.000002        69178.313           0.000
# L5.avgtemp_BRE        -0.016003              NAN              NAN             NAN
# L5.avgtemp_NOR        -0.115898         0.000001      -114510.724           0.000
# L5.avgtemp_CVL        -0.270261              NAN              NAN             NAN
# L5.avgtemp_NAQ        -0.251559         0.000002      -128925.686           0.000
# L5.daysoff             0.223810              NAN              NAN             NAN
# L5.gdp_PDL            -0.373791              NAN              NAN             NAN
# L5.gdp_BRE             0.155886              NAN              NAN             NAN
# L5.gdp_NOR             0.055495              NAN              NAN             NAN
# L5.gdp_CVL             0.385084              NAN              NAN             NAN
# L5.gdp_NAQ             0.089843              NAN              NAN             NAN
# L6.nights_PDL          1.488447              NAN              NAN             NAN
# L6.nights_BRE          0.455932         0.000000      2746942.780           0.000
# L6.nights_NOR         -0.162621         0.000000     -2431228.877           0.000
# L6.nights_CVL         -0.348426              NAN              NAN             NAN
# L6.nights_NAQ         -1.111908              NAN              NAN             NAN
# L6.avgtemp_PDL         0.288325         0.000002       121950.492           0.000
# L6.avgtemp_BRE         0.159586         0.000001       118314.889           0.000
# L6.avgtemp_NOR         0.201567         0.000002        88729.903           0.000
# L6.avgtemp_CVL         0.745497              NAN              NAN             NAN
# L6.avgtemp_NAQ         0.449255         0.000002       290351.694           0.000
# L6.daysoff            -0.339501              NAN              NAN             NAN
# L6.gdp_PDL             0.406059         0.000000    293552133.037           0.000
# L6.gdp_BRE            -0.458336         0.000000   -102567964.386           0.000
# L6.gdp_NOR             0.044818         0.000000      3620122.272           0.000
# L6.gdp_CVL            -0.411368              NAN              NAN             NAN
# L6.gdp_NAQ             0.000618              NAN              NAN             NAN
# =================================================================================
#
# Results for equation avgtemp_PDL
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -0.014188         0.000000     -1852738.734           0.000
# L1.nights_PDL          0.018386              NAN              NAN             NAN
# L1.nights_BRE          0.007669              NAN              NAN             NAN
# L1.nights_NOR          0.004742              NAN              NAN             NAN
# L1.nights_CVL         -0.021613              NAN              NAN             NAN
# L1.nights_NAQ         -0.012769         0.000000     -1382563.586           0.000
# L1.avgtemp_PDL        -0.051595              NAN              NAN             NAN
# L1.avgtemp_BRE        -0.046120         0.000000      -310357.340           0.000
# L1.avgtemp_NOR        -0.048804              NAN              NAN             NAN
# L1.avgtemp_CVL        -0.039173         0.000000      -171864.322           0.000
# L1.avgtemp_NAQ        -0.020671              NAN              NAN             NAN
# L1.daysoff            -0.022326         0.000000      -165996.820           0.000
# L1.gdp_PDL             0.020819         0.000000     65962859.579           0.000
# L1.gdp_BRE            -0.003327              NAN              NAN             NAN
# L1.gdp_NOR            -0.009728              NAN              NAN             NAN
# L1.gdp_CVL            -0.009950              NAN              NAN             NAN
# L1.gdp_NAQ            -0.004785              NAN              NAN             NAN
# L2.nights_PDL          0.005190              NAN              NAN             NAN
# L2.nights_BRE         -0.005932         0.000000      -594701.079           0.000
# L2.nights_NOR         -0.001238         0.000000      -221688.480           0.000
# L2.nights_CVL          0.057197         0.000000      3423982.395           0.000
# L2.nights_NAQ         -0.008809              NAN              NAN             NAN
# L2.avgtemp_PDL        -0.010620         0.000000      -189626.195           0.000
# L2.avgtemp_BRE        -0.005106         0.000000       -51718.469           0.000
# L2.avgtemp_NOR        -0.009886              NAN              NAN             NAN
# L2.avgtemp_CVL        -0.031613              NAN              NAN             NAN
# L2.avgtemp_NAQ        -0.022500         0.000000      -139206.509           0.000
# L2.daysoff             0.047979         0.000000       704328.258           0.000
# L2.gdp_PDL            -0.002364              NAN              NAN             NAN
# L2.gdp_BRE            -0.028124              NAN              NAN             NAN
# L2.gdp_NOR             0.006157         0.000000     12804173.725           0.000
# L2.gdp_CVL             0.005358         0.000000      4397947.023           0.000
# L2.gdp_NAQ             0.009948         0.000000     35702044.713           0.000
# L3.nights_PDL         -0.072368              NAN              NAN             NAN
# L3.nights_BRE          0.101393              NAN              NAN             NAN
# L3.nights_NOR          0.001597              NAN              NAN             NAN
# L3.nights_CVL         -0.071337              NAN              NAN             NAN
# L3.nights_NAQ          0.002405         0.000000       630959.787           0.000
# L3.avgtemp_PDL        -0.041440              NAN              NAN             NAN
# L3.avgtemp_BRE        -0.035545         0.000000      -174324.151           0.000
# L3.avgtemp_NOR        -0.050578         0.000000      -881406.328           0.000
# L3.avgtemp_CVL        -0.054855              NAN              NAN             NAN
# L3.avgtemp_NAQ        -0.043660         0.000000      -394606.461           0.000
# L3.daysoff            -0.002810         0.000000       -61082.998           0.000
# L3.gdp_PDL             0.007052         0.000000     14439481.627           0.000
# L3.gdp_BRE             0.002764         0.000000      4858889.451           0.000
# L3.gdp_NOR             0.003178              NAN              NAN             NAN
# L3.gdp_CVL            -0.016023              NAN              NAN             NAN
# L3.gdp_NAQ            -0.001022              NAN              NAN             NAN
# ...
# L3.gdp_NOR             0.582147              NAN              NAN             NAN
# L3.gdp_CVL            -1.213088              NAN              NAN             NAN
# L3.gdp_NAQ             0.435036              NAN              NAN             NAN
# L4.nights_PDL          0.748365              NAN              NAN             NAN
# L4.nights_BRE         -6.510155              NAN              NAN             NAN
# L4.nights_NOR         11.272658         0.000001      7519119.124           0.000
# L4.nights_CVL        -10.984376         0.000001    -12741831.046           0.000
# L4.nights_NAQ          6.243320              NAN              NAN             NAN
# L4.avgtemp_PDL        -3.249812         0.000029      -111495.054           0.000
# L4.avgtemp_BRE        -3.869102         0.000005      -735484.174           0.000
# L4.avgtemp_NOR        -2.636754         0.000009      -284701.380           0.000
# L4.avgtemp_CVL        -3.558559              NAN              NAN             NAN
# L4.avgtemp_NAQ        -5.437134              NAN              NAN             NAN
# L4.daysoff             2.998313         0.000012       248127.631           0.000
# L4.gdp_PDL            -0.088078         0.000000     -1621948.642           0.000
# L4.gdp_BRE            -0.394500         0.000000    -13043192.621           0.000
# L4.gdp_NOR             1.056360         0.000000     24910835.305           0.000
# L4.gdp_CVL            -1.415837              NAN              NAN             NAN
# L4.gdp_NAQ             0.411230              NAN              NAN             NAN
# L5.nights_PDL          7.540512              NAN              NAN             NAN
# L5.nights_BRE          1.542066         0.000000      3613046.991           0.000
# L5.nights_NOR          0.945349         0.000001       905049.282           0.000
# L5.nights_CVL          4.539342         0.000001      3550560.354           0.000
# L5.nights_NAQ         -0.375826              NAN              NAN             NAN
# L5.avgtemp_PDL        -3.137662         0.000018      -173318.089           0.000
# L5.avgtemp_BRE        -2.387820              NAN              NAN             NAN
# L5.avgtemp_NOR        -4.342330         0.000009      -483170.787           0.000
# L5.avgtemp_CVL        -5.127924              NAN              NAN             NAN
# L5.avgtemp_NAQ        -2.246864         0.000017      -129683.119           0.000
# L5.daysoff            -2.553630              NAN              NAN             NAN
# L5.gdp_PDL             1.316248              NAN              NAN             NAN
# L5.gdp_BRE            -2.455950              NAN              NAN             NAN
# L5.gdp_NOR             0.489245              NAN              NAN             NAN
# L5.gdp_CVL            -1.629404              NAN              NAN             NAN
# L5.gdp_NAQ             0.082911              NAN              NAN             NAN
# L6.nights_PDL         -3.341145              NAN              NAN             NAN
# L6.nights_BRE          3.388301         0.000001      2298995.766           0.000
# L6.nights_NOR          1.962111         0.000001      3303531.700           0.000
# L6.nights_CVL         -0.662122              NAN              NAN             NAN
# L6.nights_NAQ          2.617349              NAN              NAN             NAN
# L6.avgtemp_PDL        -2.551804         0.000021      -121550.055           0.000
# L6.avgtemp_BRE        -2.126452         0.000012      -177543.686           0.000
# L6.avgtemp_NOR        -1.989134         0.000020       -98609.745           0.000
# L6.avgtemp_CVL        -2.188177              NAN              NAN             NAN
# L6.avgtemp_NAQ        -2.500678         0.000014      -182010.160           0.000
# L6.daysoff             3.620091              NAN              NAN             NAN
# L6.gdp_PDL             2.089346         0.000000    170103271.434           0.000
# L6.gdp_BRE             1.207667         0.000000     30435556.363           0.000
# L6.gdp_NOR            -1.348991         0.000000    -12271065.308           0.000
# L6.gdp_CVL            -1.648171              NAN              NAN             NAN
# L6.gdp_NAQ            -0.932579              NAN              NAN             NAN
# =================================================================================
#
# Results for equation gdp_NAQ
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -5.841051         0.000003     -1741560.987           0.000
# L1.nights_PDL         12.816662              NAN              NAN             NAN
# L1.nights_BRE         10.626539              NAN              NAN             NAN
# L1.nights_NOR        -23.122348              NAN              NAN             NAN
# L1.nights_CVL         -4.354598              NAN              NAN             NAN
# L1.nights_NAQ         -6.604259         0.000004     -1632672.552           0.000
# L1.avgtemp_PDL       -10.817319              NAN              NAN             NAN
# L1.avgtemp_BRE       -11.411267         0.000065      -175328.661           0.000
# L1.avgtemp_NOR       -13.611864              NAN              NAN             NAN
# L1.avgtemp_CVL        -6.924152         0.000100       -69360.936           0.000
# L1.avgtemp_NAQ         0.895867              NAN              NAN             NAN
# L1.daysoff            -6.596895         0.000059      -111988.110           0.000
# L1.gdp_PDL             0.581975         0.000000      4210022.588           0.000
# L1.gdp_BRE             1.790272              NAN              NAN             NAN
# L1.gdp_NOR            -3.052202              NAN              NAN             NAN
# L1.gdp_CVL             2.715883              NAN              NAN             NAN
# L1.gdp_NAQ            -0.338617              NAN              NAN             NAN
# L2.nights_PDL         24.361868              NAN              NAN             NAN
# L2.nights_BRE        -24.055317         0.000004     -5506007.632           0.000
# L2.nights_NOR         -8.075390         0.000002     -3302772.775           0.000
# L2.nights_CVL          5.105320         0.000007       697796.271           0.000
# L2.nights_NAQ         -2.393143              NAN              NAN             NAN
# L2.avgtemp_PDL        -1.227400         0.000025       -50037.892           0.000
# L2.avgtemp_BRE        -1.278412         0.000043       -29567.105           0.000
# L2.avgtemp_NOR         0.448200              NAN              NAN             NAN
# L2.avgtemp_CVL        -3.051279              NAN              NAN             NAN
# L2.avgtemp_NAQ        -0.806927         0.000071       -11398.777           0.000
# L2.daysoff             6.449465         0.000030       216173.144           0.000
# L2.gdp_PDL            -0.790320              NAN              NAN             NAN
# L2.gdp_BRE            -3.995165              NAN              NAN             NAN
# L2.gdp_NOR             0.222071         0.000000      1054376.671           0.000
# L2.gdp_CVL             1.957762         0.000001      3669338.629           0.000
# L2.gdp_NAQ             1.988290         0.000000     16292546.433           0.000
# L3.nights_PDL        -14.263739              NAN              NAN             NAN
# L3.nights_BRE          2.460872              NAN              NAN             NAN
# L3.nights_NOR          3.556412              NAN              NAN             NAN
# L3.nights_CVL        -24.528783              NAN              NAN             NAN
# L3.nights_NAQ         10.066880         0.000002      6030324.593           0.000
# L3.avgtemp_PDL       -11.405944              NAN              NAN             NAN
# L3.avgtemp_BRE        -8.480458         0.000089       -94960.686           0.000
# L3.avgtemp_NOR       -12.092943         0.000025      -481167.044           0.000
# L3.avgtemp_CVL       -12.876271              NAN              NAN             NAN
# L3.avgtemp_NAQ       -10.354376         0.000048      -213676.377           0.000
# L3.daysoff             3.013505         0.000020       149561.134           0.000
# L3.gdp_PDL             0.019406         0.000000        90720.153           0.000
# L3.gdp_BRE            -0.028204         0.000000      -113221.408           0.000
# L3.gdp_NOR             2.114842              NAN              NAN             NAN
# L3.gdp_CVL            -3.833856              NAN              NAN             NAN
# L3.gdp_NAQ             0.660006              NAN              NAN             NAN
# L4.nights_PDL          6.760570              NAN              NAN             NAN
# L4.nights_BRE        -15.701725              NAN              NAN             NAN
# L4.nights_NOR         14.917537         0.000005      2752929.409           0.000
# L4.nights_CVL        -23.089469         0.000003     -7410161.811           0.000
# L4.nights_NAQ          9.611374              NAN              NAN             NAN
# L4.avgtemp_PDL        -9.257346         0.000105       -87870.115           0.000
# L4.avgtemp_BRE        -8.391212         0.000019      -441311.389           0.000
# L4.avgtemp_NOR        -6.385602         0.000033      -190756.422           0.000
# L4.avgtemp_CVL       -10.440914              NAN              NAN             NAN
# L4.avgtemp_NAQ       -11.528522              NAN              NAN             NAN
# L4.daysoff             5.609483         0.000044       128433.491           0.000
# L4.gdp_PDL            -1.221948         0.000000     -6225574.402           0.000
# L4.gdp_BRE            -3.525351         0.000000    -32247544.612           0.000
# L4.gdp_NOR             4.739964         0.000000     30924921.457           0.000
# L4.gdp_CVL            -3.713164              NAN              NAN             NAN
# L4.gdp_NAQ             1.966097              NAN              NAN             NAN
# L5.nights_PDL          7.810240              NAN              NAN             NAN
# L5.nights_BRE          6.610519         0.000002      4285126.221           0.000
# L5.nights_NOR         -6.859910         0.000004     -1817002.981           0.000
# L5.nights_CVL         16.669699         0.000005      3607356.788           0.000
# L5.nights_NAQ          7.259604              NAN              NAN             NAN
# L5.avgtemp_PDL        -4.662422         0.000065       -71253.571           0.000
# L5.avgtemp_BRE        -2.269917              NAN              NAN             NAN
# L5.avgtemp_NOR        -4.806649         0.000032      -147971.324           0.000
# L5.avgtemp_CVL        -4.572419              NAN              NAN             NAN
# L5.avgtemp_NAQ        -1.623942         0.000063       -25931.905           0.000
# L5.daysoff            -9.069372              NAN              NAN             NAN
# L5.gdp_PDL             3.353794              NAN              NAN             NAN
# L5.gdp_BRE            -3.584553              NAN              NAN             NAN
# L5.gdp_NOR             0.637584              NAN              NAN             NAN
# L5.gdp_CVL            -4.234248              NAN              NAN             NAN
# L5.gdp_NAQ            -0.146084              NAN              NAN             NAN
# L6.nights_PDL        -25.729639              NAN              NAN             NAN
# L6.nights_BRE         -4.687789         0.000005      -879997.586           0.000
# L6.nights_NOR         28.653657         0.000002     13347261.765           0.000
# L6.nights_CVL          4.723492              NAN              NAN             NAN
# L6.nights_NAQ          4.809769              NAN              NAN             NAN
# L6.avgtemp_PDL        -2.842932         0.000076       -37465.511           0.000
# L6.avgtemp_BRE        -1.604542         0.000043       -37064.481           0.000
# L6.avgtemp_NOR        -2.296355         0.000073       -31495.770           0.000
# L6.avgtemp_CVL        -5.638030              NAN              NAN             NAN
# L6.avgtemp_NAQ        -3.110635         0.000050       -62638.918           0.000
# L6.daysoff             7.503990              NAN              NAN             NAN
# L6.gdp_PDL             2.541576         0.000000     57248302.769           0.000
# L6.gdp_BRE             3.947031         0.000000     27520863.682           0.000
# L6.gdp_NOR            -3.233360         0.000000     -8137378.418           0.000
# L6.gdp_CVL            -1.445478              NAN              NAN             NAN
# L6.gdp_NAQ            -2.119397              NAN              NAN             NAN
# =================================================================================
#
# Correlation matrix of residuals
#                nights_PDL  nights_BRE  nights_NOR  nights_CVL  nights_NAQ  avgtemp_PDL  avgtemp_BRE  avgtemp_NOR  avgtemp_CVL  avgtemp_NAQ   daysoff   gdp_PDL   gdp_BRE   gdp_NOR   gdp_CVL   gdp_NAQ
# nights_PDL       1.000000    0.633723    0.099411    0.791925    0.560938    -0.749666    -0.819231    -0.831923    -0.853397    -0.802036  0.507140 -0.758096 -0.768389 -0.671221 -0.751489 -0.750412
# nights_BRE       0.633723    1.000000    0.620402    0.843992    0.677251    -0.843633    -0.648114    -0.773416    -0.822118    -0.885815  0.710619 -0.746779 -0.710934 -0.715697 -0.703233 -0.692012
# nights_NOR       0.099411    0.620402    1.000000    0.308844    0.399842    -0.334014     0.009394    -0.126298    -0.290009    -0.366636  0.707442 -0.224554 -0.136356 -0.336473 -0.070490 -0.259235
# nights_CVL       0.791925    0.843992    0.308844    1.000000    0.759545    -0.873539    -0.823542    -0.867842    -0.890267    -0.884701  0.571403 -0.815853 -0.812381 -0.695435 -0.787999 -0.769742
# nights_NAQ       0.560938    0.677251    0.399842    0.759545    1.000000    -0.496640    -0.434237    -0.585158    -0.551007    -0.608614  0.722620 -0.498833 -0.426512 -0.353285 -0.553016 -0.381315
# avgtemp_PDL     -0.749666   -0.843633   -0.334014   -0.873539   -0.496640     1.000000     0.869594     0.898871     0.969073     0.960474 -0.536972  0.869772  0.892364  0.824381  0.782653  0.804388
# avgtemp_BRE     -0.819231   -0.648114    0.009394   -0.823542   -0.434237     0.869594     1.000000     0.898060     0.909952     0.848474 -0.318522  0.855616  0.916659  0.779519  0.802127  0.860890
# avgtemp_NOR     -0.831923   -0.773416   -0.126298   -0.867842   -0.585158     0.898871     0.898060     1.000000     0.930787     0.931493 -0.489710  0.929537  0.898104  0.824636  0.908578  0.833691
# avgtemp_CVL     -0.853397   -0.822118   -0.290009   -0.890267   -0.551007     0.969073     0.909952     0.930787     1.000000     0.968416 -0.578508  0.902639  0.920356  0.852945  0.838171  0.853188
# avgtemp_NAQ     -0.802036   -0.885815   -0.366636   -0.884701   -0.608614     0.960474     0.848474     0.931493     0.968416     1.000000 -0.656157  0.896442  0.867653  0.836344  0.843189  0.802932
# daysoff          0.507140    0.710619    0.707442    0.571403    0.722620    -0.536972    -0.318522    -0.489710    -0.578508    -0.656157  1.000000 -0.447735 -0.385377 -0.405836 -0.449474 -0.349225
# gdp_PDL         -0.758096   -0.746779   -0.224554   -0.815853   -0.498833     0.869772     0.855616     0.929537     0.902639     0.896442 -0.447735  1.000000  0.936003  0.930964  0.903932  0.907872
# gdp_BRE         -0.768389   -0.710934   -0.136356   -0.812381   -0.426512     0.892364     0.916659     0.898104     0.920356     0.867653 -0.385377  0.936003  1.000000  0.875255  0.888105  0.880027
# gdp_NOR         -0.671221   -0.715697   -0.336473   -0.695435   -0.353285     0.824381     0.779519     0.824636     0.852945     0.836344 -0.405836  0.930964  0.875255  1.000000  0.823714  0.913516
# gdp_CVL         -0.751489   -0.703233   -0.070490   -0.787999   -0.553016     0.782653     0.802127     0.908578     0.838171     0.843189 -0.449474  0.903932  0.888105  0.823714  1.000000  0.768445
# gdp_NAQ         -0.750412   -0.692012   -0.259235   -0.769742   -0.381315     0.804388     0.860890     0.833691     0.853188     0.802932 -0.349225  0.907872  0.880027  0.913516  0.768445  1.000000

# %%
add_residual.values.shape
#add_residual.values.dtype
# Out:
# (60, 16)

# %%
lag_order = results.k_ar
print(lag_order)

add_resid_forecast_2016 = results.forecast(add_residual.values[-lag_order:], 12)
# Out:
# 6

# %%
add_resid_forecast_2016_df = pd.DataFrame(add_resid_forecast_2016)
add_resid_forecast_2016_df.head()
# Out:
#           0          1          2          3          4         5         6   \
# 0  -2.689646   4.617104  36.673118   8.052285  29.166868  2.324306  1.803472
# 1 -21.918063  13.136187  10.196868  13.251951 -31.572299  0.315972  0.236806
# 2  -4.777396   2.690021  10.596035   7.404535 -11.006049 -0.509028 -0.538194
# 3 -12.196479 -12.515229 -16.060382  -6.872632  -8.252465 -1.875694 -1.063194
# 4  -2.692313 -22.831562 -33.113882 -15.791715 -17.810882 -1.400694 -1.354861
#
#          7         8         9         10          11          12          13  \
# 0  2.185417  2.529167  2.125103  0.863889 -110.655228  -66.228940  -75.593194
# 1  0.260417  0.529167  0.155126 -1.311111 -331.965683 -198.686821 -226.779583
# 2 -0.239583 -0.470833 -0.879478 -0.119444 -553.276139 -331.144701 -377.965972
# 3 -1.172917 -1.270833 -1.371127  1.438889 -774.586595 -463.602581 -529.152361
# 4 -0.906250 -1.237500 -1.460360 -0.061111 -995.897050 -596.060462 -680.338750
#
#            14           15
# 0  -50.324587  -132.830626
# 1 -150.973760  -398.491877
# 2 -251.622934  -664.153129
# 3 -352.272107  -929.814381
# 4 -452.921280 -1195.475632

# %%
add_seasonal_2016_array = add_seasonal_2016.nights_PDL.values
add_seasonal_2016_df = pd.DataFrame(add_seasonal_2016_array)
add_seasonal_2016_df.head(2)
# Out:
#             0
# 0 -169.663271
# 1 -153.071438

# %%
forecast_2016 = add_seasonal_2016_df[0] + (arima_trend_forecast_2016_df[0] + add_resid_forecast_2016_df[0])
forecast_2016
# Out:
# 0     380.579425
# 1     379.081804
# 2     466.988474
# 3     534.217000
# 4     603.574624
# 5     722.817774
# 6     737.606217
# 7     820.598976
# 8     649.577877
# 9     565.951809
# 10    427.740304
# 11    421.807764
# Name: 0, dtype: float64

# %%
nights_PDL_2016 = nights_PDL[(nights_PDL.index>='2016-01-01')&(nights_PDL.index<'2017-01-01')]
nights_PDL_2016 = np.array(nights_PDL_2016.nights_PDL)
nights_PDL_2016_df = pd.DataFrame(nights_PDL_2016)

# %%
results.aic
# Out:
# -884.4567000336763

# %%
# Define seasonality as 12 (monthly data) in argument when ground truth data includes at least 24 months

def seasonal_MASE(truth, forecast, seasonality=1):    
    period = truth.shape[0] # T
    # print(period)
    forecast_errors = np.abs(truth - forecast)
    # print(forecast_errors)
    mean_absolute_forecast_error = np.sum(forecast_errors) / period
    # print(mean_absolute_forecast_error)

    naive_period = truth.shape[0] - seasonality # T - m
    # print(naive_period)
    # print(truth[seasonality:])
    # print(truth[:period - seasonality])
    naive_errors = np.abs(truth[seasonality:] - truth[:period - seasonality])
    mean_absolute_naive_error = np.sum(naive_errors) / naive_period
    
    return mean_absolute_forecast_error / mean_absolute_naive_error

# %%
MASE_2016 = seasonal_MASE(nights_PDL_2016, forecast_2016)
print('MASE: %f' % MASE_2016)
# Out:
# MASE: 0.385354

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

rmse_2016 = np.sqrt(mean_squared_error(nights_PDL_2016, forecast_2016))
mae_2016 = mean_absolute_error(nights_PDL_2016, forecast_2016)
print('RMSE:', rmse_2016)
print('MAE:', mae_2016)
# Out:
# RMSE: 40.3720858920871
# MAE: 33.9448230769086

# %%
nights_PDL_2016_df.plot(label='Real')
forecast_2016.plot(label='Forecast')
plt.legend()

# %%
# # Gives me second block in array
# print(add_residual.values[1])

# # Gives me last block in array
# print(add_residual.values[-1])

# # Removes first block and gives me the last 2
# print(add_residual.values[-1:2])

# # Gives me only the last 3 blocks
# print(add_residual.values[-3:])

# # Gives me the first block in the array
# print(add_residual.values[0])

# # Gives me from the second block to the last block in the array
# print(add_residual.values[1:])
